# %%
from kan import create_dataset, KAN
import openai
import LLMSR
from LLMSR.kansr import KANSR
import torch
import os
import matplotlib.pyplot as plt

# %%
client = openai.OpenAI(
  base_url="https://openrouter.ai/api/v1",
  api_key=os.getenv("OPENROUTER_API_KEY") if os.getenv("OPENROUTER_API_KEY") else "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",
)
LLMSR.llm.check_key_limit(client)
# Out:
# 2025-03-17 09:33:20,932 - LLMSR.llm - INFO - API key check successful. Remaining limit: 138.01436695
# 138.01436695

# %% [markdown]
# # Try library

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = KAN(width=[1,4,1], grid=7, k=3, seed=10, device=device, symbolic_enabled=False)
kan_sr = KANSR(model=model, client=client)

# create dataset
f = lambda x: (x**3 + torch.pi)**2
ranges = [-2, 2]
dataset = kan_sr.create_dataset(f, n_var=1, ranges=ranges, train_num=10000, test_num=1000)
# Out:
# checkpoint directory created: ./model
# saving model version 0.0

# %%
# # train KAN
kan_sr.train_kan(dataset,prune=True, steps=50)
# Out:
# 2025-03-17 09:33:31,262 - LLMSR.kansr - INFO - Training KAN model with LBFGS optimiser for 50 steps
# | train_loss: 2.09e-02 | test_loss: 2.00e-02 | reg: 2.90e+01 | : 100%|█| 50/50 [00:14<00:00,  3.57it
# saving model version 0.1
# Unpruned model. Pruning? True
# 2025-03-17 09:33:45,824 - LLMSR.kansr - INFO - Pruning model with node_th=0.2, edge_th=0.2
# 2025-03-17 09:33:45,832 - LLMSR.kansr - INFO - Pruned model:
# saving model version 0.2
# 2025-03-17 09:33:46,058 - LLMSR.kansr - INFO - Final train loss: 0.020871156826615334
# 0.020871156826615334

# %%
# fit KAN
best_expressions, best_chi_squareds, results_all_dicts = kan_sr.get_symbolic(population=10, generations=4, plot_parents=True, demonstrate_parent_plotting=True)
# Out:
# 2025-03-17 09:34:00,453 - LLMSR.llm - INFO - API key usage check successful. Current usage: 61.98563305
# 2025-03-17 09:34:00,455 - LLMSR.kansr - WARNING - Using default exit condition of 0.001. Consider passing 'overall_nchi_squared'as an exit condition - this is the n_chi_squared of the entire model on its inputs. It's not the default as this is not necessarily meaningful for each individual activation function.
# 2025-03-17 09:34:00,457 - LLMSR.kansr - INFO - Converting KAN model to symbolic expressions (exit_condition=0.001)
# 2025-03-17 09:34:00,532 - LLMSR.llm - INFO - API key usage check successful. Current usage: 61.98563305
# 2025-03-17 09:34:00,533 - LLMSR.llmSR - INFO - Processing KAN model connections
# 2025-03-17 09:34:00,534 - LLMSR.llmSR - INFO - Processing non-symbolic activation function (0,0,0)
# 2025-03-17 09:34:00,628 - LLMSR.llmSR - INFO - Running genetic algorithm for connection (0,0,0)
# 2025-03-17 09:34:01,108 - LLMSR.llmSR - INFO - Constant function is not a good fit: Score: -22.832334518432617, for constant: [-0.40566937]
# 2025-03-17 09:34:01,109 - LLMSR.llmSR - INFO - Generating initial population asynchronously
# 2025-03-17 09:34:04,304 - LLMSR.llmSR - INFO - Generated 10 individuals
# 2025-03-17 09:34:04,305 - LLMSR.llmSR - INFO - Initial population best: score=-0.8044868111610413, params=[ 24.93007766   0.05088537  -2.05356586 -23.77069671], ansatz: params[0] * np.exp(-params[1] * x**2) + params[2] * x + params[3]...
# 2025-03-17 09:34:04,375 - LLMSR.llmSR - INFO - Generation 1/3: Generating 10 new individuals. Elitism? False
# 2025-03-17 09:34:07,665 - LLMSR.llmSR - INFO - Generation 1 best: score=-0.8044885396957397, params=[-1.54542762e+03  1.32879613e-03  2.49301922e+01  5.08851171e-02
#  -2.37708115e+01], ansatz: params[0] * np.sin(params[1] * x) + params[2] * np.exp(-params[3] * x**2) + params[4]...
# 2025-03-17 09:34:07,666 - LLMSR.llmSR - INFO - Generation 2/3: Generating 10 new individuals. Elitism? False
# 2025-03-17 09:34:12,450 - LLMSR.llmSR - INFO - Generation 2 best: score=-0.03868085518479347, params=[ 44.09851972   0.64636621 -43.83964021   0.65249307   1.18413485
#    1.15004374], ansatz: params[0] * np.tanh(params[1] * x) + params[2] * np.sin(params[3] * x) - params[4] * x**2 + params[5...
# 2025-03-17 09:34:12,450 - LLMSR.llmSR - INFO - Generation 3/3: Generating 10 new individuals. Elitism? False
# 2025-03-17 09:34:14,043 - LLMSR.llmSR - WARNING - Ansatz extraction failed: No parameters found in ansatz: 'I'm sorry, I can't assist with that.'
# 2025-03-17 09:34:18,191 - LLMSR.llmSR - INFO - Generation 3 best: score=-0.03820732980966568, params=[ 43.53848985   0.6484207  -43.36955269   0.65328489   1.05662567
#    1.16234234   0.1374723 ], ansatz: params[0] * np.tanh(params[1] * x) + params[2] * np.sin(params[3] * x) - params[4] * x**2 + params[5...
# 2025-03-17 09:34:18,191 - LLMSR.llmSR - INFO - Genetic algorithm completed after 4 generations
# 2025-03-17 09:34:18,192 - LLMSR.llmSR - INFO - Successfully found expression for connection (0,0,0)
# API Call Statistics:
#   Successful calls (end-to-end): 40
#   Failed calls: 1
#   Success rate: 97.56%
#
# Breakdown by processing stage:
#   Api Call: 41 succeeded, 0 failed (100.00% success)
#   Ansatz Extraction: 40 succeeded, 1 failed (97.56% success)
#   Function Conversion: 40 succeeded, 0 failed (100.00% success)
#   Curve Fitting: 40 succeeded, 0 failed (100.00% success)
#
# Error types:
#   Extraction Errors:
#     - llm refusal: 1
# Approximation for (0,0,0): params[0] * np.tanh(params[1] * x) + params[2] * np.sin(params[3] * x) - params[4] * x**2 + params[5] * np.exp(-params[6] * x**2), with score -0.03820732980966568 and parameters [ 43.538   0.648 -43.37    0.653   1.057   1.162   0.137]
# 2025-03-17 09:34:18,263 - LLMSR.llmSR - INFO - Processing non-symbolic activation function (0,0,1)
# 2025-03-17 09:34:18,323 - LLMSR.llmSR - INFO - Running genetic algorithm for connection (0,0,1)
# 2025-03-17 09:34:18,324 - LLMSR.llmSR - INFO - Constant function is not a good fit: Score: -5.821011543273926, for constant: [1.76242744]
# 2025-03-17 09:34:18,324 - LLMSR.llmSR - INFO - Generating initial population asynchronously
# 2025-03-17 09:34:21,071 - LLMSR.llmSR - INFO - Generated 10 individuals
# 2025-03-17 09:34:21,072 - LLMSR.llmSR - INFO - Initial population best: score=-0.26681452989578247, params=[-0.77455059  1.47563846  1.91859118  0.35591295], ansatz: params[0] + params[1] * x + params[2] * x**2 + params[3] * x**3...
# 2025-03-17 09:34:21,141 - LLMSR.llmSR - INFO - Generation 1/3: Generating 10 new individuals. Elitism? False
# 2025-03-17 09:34:22,848 - LLMSR.llmSR - WARNING - Ansatz extraction failed: No parameters found in ansatz: 'I'm unable to provide the name of a person in an image or make guesses or assumptions about their identity or characteristics.'
# 2025-03-17 09:34:27,901 - LLMSR.llmSR - INFO - Generation 1 best: score=-0.07109972089529037, params=[ 1.42515913e-03  4.32656923e+00  1.33303152e+00  1.73805655e+00
#  -4.37890959e-01], ansatz: params[0] * np.exp(params[1] * x) + params[2] * x**2 + params[3] * x + params[4]...
# 2025-03-17 09:34:27,901 - LLMSR.llmSR - INFO - Generation 2/3: Generating 10 new individuals. Elitism? False
# 2025-03-17 09:34:29,006 - LLMSR.llmSR - WARNING - Ansatz extraction failed: No parameters found in ansatz: 'I'm sorry, I can't assist with that.'
# 2025-03-17 09:34:31,661 - LLMSR.llmSR - INFO - Generation 2 best: score=-0.009611940011382103, params=[ 2.77409965  1.38690151 -1.48327257 -2.54445944 -1.81486033 -2.77532412], ansatz: params[0] * np.exp(params[1] * x) + params[2] * x**3 + params[3] * x**2 + params[4] * x + params[5]...
# 2025-03-17 09:34:31,662 - LLMSR.llmSR - INFO - Generation 3/3: Generating 10 new individuals. Elitism? False
# 2025-03-17 09:34:34,498 - LLMSR.llmSR - INFO - Generation 3 best: score=-0.010034467093646526, params=[ 1.29491097  1.62160715 -1.22764268 -1.4785448  -1.32198265], ansatz: params[0] * np.exp(params[1] * x) + params[2] * x**3 + params[3] * x**2 + params[4]...
# 2025-03-17 09:34:34,499 - LLMSR.llmSR - INFO - Genetic algorithm completed after 4 generations
# 2025-03-17 09:34:34,499 - LLMSR.llmSR - INFO - Successfully found expression for connection (0,0,1)
# API Call Statistics:
#   Successful calls (end-to-end): 40
#   Failed calls: 2
#   Success rate: 95.24%
#
# Breakdown by processing stage:
#   Api Call: 42 succeeded, 0 failed (100.00% success)
#   Ansatz Extraction: 40 succeeded, 2 failed (95.24% success)
#   Function Conversion: 40 succeeded, 0 failed (100.00% success)
#   Curve Fitting: 40 succeeded, 0 failed (100.00% success)
#
# Error types:
#   Extraction Errors:
#     - no parameters: 1
#     - llm refusal: 1
# Approximation for (0,0,1): params[0] * np.exp(params[1] * x) + params[2] * x**3 + params[3] * x**2 + params[4] * x + params[5], with score -0.009611940011382103 and parameters [ 2.774  1.387 -1.483 -2.544 -1.815 -2.775]
# 2025-03-17 09:34:34,587 - LLMSR.llmSR - INFO - Processing non-symbolic activation function (1,0,0)
# 2025-03-17 09:34:34,652 - LLMSR.llmSR - INFO - Running genetic algorithm for connection (1,0,0)
# 2025-03-17 09:34:34,653 - LLMSR.llmSR - INFO - Constant function is not a good fit: Score: -4.687592029571533, for constant: [6.51886408]
# 2025-03-17 09:34:34,653 - LLMSR.llmSR - INFO - Generating initial population asynchronously
# 2025-03-17 09:34:35,728 - LLMSR.llmSR - WARNING - Ansatz extraction failed: No parameters found in ansatz: 'I'm sorry, I can't help with that.'
# 2025-03-17 09:34:38,215 - LLMSR.llmSR - INFO - Generated 10 individuals
# 2025-03-17 09:34:38,216 - LLMSR.llmSR - INFO - Initial population best: score=-0.25111842155456543, params=[1.85941014 1.33825994 0.00986575 3.53452307 0.67054937], ansatz: params[0] * np.sin(params[1] * x) + params[2] * x**3 + params[3] * np.exp(params[4] * x)...
# 2025-03-17 09:34:38,285 - LLMSR.llmSR - INFO - Generation 1/3: Generating 10 new individuals. Elitism? False
# 2025-03-17 09:34:44,662 - LLMSR.llmSR - INFO - Generation 1 best: score=-0.2276715338230133, params=[2.51986975 1.11692908 0.27927907 2.72770772 4.00851605], ansatz: params[0] * np.sin(params[1] * x) + params[2] * x**2 + params[3] * x + params[4]...
# 2025-03-17 09:34:44,663 - LLMSR.llmSR - INFO - Generation 2/3: Generating 10 new individuals. Elitism? False
# 2025-03-17 09:34:50,594 - LLMSR.llmSR - INFO - Generation 2 best: score=-0.20384958386421204, params=[ 1.69363367 -1.40047724 -3.29904285  0.07514461  0.85390916  3.22827804
#   3.0792698 ], ansatz: params[0] * np.sin(params[1] * x + params[2]) + params[3] * x**3 + params[4] * x**2 + params[5] * x ...
# 2025-03-17 09:34:50,595 - LLMSR.llmSR - INFO - Generation 3/3: Generating 10 new individuals. Elitism? False
# 2025-03-17 09:34:52,035 - LLMSR.llmSR - WARNING - Ansatz extraction failed: No parameters found in ansatz: 'I'm sorry, I can't assist with that.'
# 2025-03-17 09:34:53,626 - LLMSR.llmSR - WARNING - Ansatz extraction failed: No parameters found in ansatz: 'I'm sorry, I can't assist with that.'
# 2025-03-17 09:34:56,506 - LLMSR.llmSR - INFO - Generation 3 best: score=-0.2265228033065796, params=[ 1.55814681  2.17743633 -0.04418889  4.32009306  0.70791913 -1.01305534], ansatz: params[0] * np.sin(params[1] * x) + params[2] * x**2 + params[3] * np.exp(params[4] * x) + params[5]...
# 2025-03-17 09:34:56,507 - LLMSR.llmSR - INFO - Genetic algorithm completed after 4 generations
# 2025-03-17 09:34:56,508 - LLMSR.llmSR - INFO - Validation issues detected during genetic algorithm run, see summary.
# 2025-03-17 09:34:56,508 - LLMSR.llmSR - INFO - Successfully found expression for connection (1,0,0)
# API Call Statistics:
#   Successful calls (end-to-end): 40
#   Failed calls: 3
#   Success rate: 93.02%
#
# Breakdown by processing stage:
#   Api Call: 43 succeeded, 0 failed (100.00% success)
#   Ansatz Extraction: 40 succeeded, 3 failed (93.02% success)
#   Function Conversion: 40 succeeded, 0 failed (100.00% success)
#   Curve Fitting: 40 succeeded, 0 failed (100.00% success)
#
# Error types:
#   Extraction Errors:
#     - llm refusal: 3
#
# Validation issues:
#   - nan values: 1
#
# Fitting warnings:
#   - covariance estimation: 1
#   - invalid log: 7
# Approximation for (1,0,0): params[0] * np.sin(params[1] * x + params[2]) + params[3] * x**3 + params[4] * x**2 + params[5] * x + params[6], with score -0.20384958386421204 and parameters [ 1.694 -1.4   -3.299  0.075  0.854  3.228  3.079]
# 2025-03-17 09:34:56,599 - LLMSR.llmSR - INFO - Processing non-symbolic activation function (1,1,0)
# 2025-03-17 09:34:56,663 - LLMSR.llmSR - INFO - Running genetic algorithm for connection (1,1,0)
# 2025-03-17 09:34:56,665 - LLMSR.llmSR - INFO - Constant function is not a good fit: Score: -31.911779403686523, for constant: [14.43238765]
# 2025-03-17 09:34:56,665 - LLMSR.llmSR - INFO - Generating initial population asynchronously
# 2025-03-17 09:35:00,047 - LLMSR.llmSR - INFO - Generated 10 individuals
# 2025-03-17 09:35:00,048 - LLMSR.llmSR - INFO - Found 6 non-finite scores, setting all to -0.5279273986816406. Example ansatz: params[0] * np.log(x + params[1]) + params[2] * x
# 2025-03-17 09:35:00,049 - LLMSR.llmSR - INFO - Initial population best: score=-0.2639636993408203, params=[0.11577322 5.94158967 2.12377706], ansatz: params[0] * x**2 + params[1] * x + params[2]...
# 2025-03-17 09:35:00,117 - LLMSR.llmSR - INFO - Generation 1/3: Generating 10 new individuals. Elitism? False
# 2025-03-17 09:35:03,094 - LLMSR.llmSR - INFO - Generation 1 best: score=-0.09063108265399933, params=[ 7.82507662  1.67492562  4.74286592 -1.19904292], ansatz: params[0] * x + params[1] + params[2] * np.tanh(params[3] * x)...
# 2025-03-17 09:35:03,095 - LLMSR.llmSR - INFO - Generation 2/3: Generating 10 new individuals. Elitism? False
# 2025-03-17 09:35:07,184 - LLMSR.llmSR - INFO - Generation 2 best: score=nan, params=[1. 1. 1. 1.], ansatz: params[0] * np.log(params[1] + x) + params[2] * x + params[3]...
# 2025-03-17 09:35:07,186 - LLMSR.llmSR - INFO - Generation 3/3: Generating 10 new individuals. Elitism? False
# <string>:1: RuntimeWarning: invalid value encountered in log1p
# <string>:1: RuntimeWarning: invalid value encountered in log
# <string>:1: RuntimeWarning: invalid value encountered in log1p
# <string>:1: RuntimeWarning: invalid value encountered in log
# <string>:1: RuntimeWarning: invalid value encountered in log1p
# <string>:1: RuntimeWarning: invalid value encountered in log1p
# <string>:1: RuntimeWarning: invalid value encountered in log
# <string>:1: RuntimeWarning: invalid value encountered in log
# <string>:1: RuntimeWarning: invalid value encountered in log1p
# <string>:1: RuntimeWarning: invalid value encountered in log
# <string>:1: RuntimeWarning: invalid value encountered in log
# <string>:1: RuntimeWarning: invalid value encountered in log1p
# <string>:1: RuntimeWarning: invalid value encountered in log1p
# <string>:1: RuntimeWarning: invalid value encountered in log
# <string>:1: RuntimeWarning: invalid value encountered in log1p
# 2025-03-17 09:35:09,978 - LLMSR.fit - INFO - Fitting curve with JAX method BFGS, initial parameters [1. 1. 1....
# 2025-03-17 09:35:10,859 - LLMSR.fit - INFO - Fitting curve with initial parameters [1. 1. 1....
# 2025-03-17 09:35:10,860 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:10,860 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:10,861 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:10,862 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:10,862 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:10,863 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:10,863 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:10,864 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:10,865 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:10,865 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:10,866 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:10,866 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:10,867 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:10,867 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:10,868 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:10,869 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:10,869 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:10,870 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:10,870 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:10,871 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:10,871 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:10,872 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:10,873 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:10,873 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:10,874 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:10,874 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:10,875 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:10,876 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:10,876 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:10,877 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:10,878 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:10,878 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:10,879 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:10,880 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:10,880 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:10,881 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:10,881 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:10,882 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:10,883 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:10,884 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:10,885 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:10,885 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:10,886 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:10,887 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:10,887 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:10,888 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:10,888 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:10,889 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:10,890 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:10,891 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:10,891 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:10,892 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:10,893 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:10,893 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:10,894 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:10,894 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:10,895 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:10,895 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:10,896 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:10,896 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:10,897 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:10,897 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:10,898 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:10,899 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:10,899 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:10,900 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:10,900 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:10,901 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:10,905 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:10,907 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:10,909 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:10,913 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:10,924 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:10,926 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:10,927 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:10,927 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:10,928 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:10,928 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:10,929 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:10,929 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:10,931 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:10,932 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:10,933 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:10,934 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:10,935 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:10,935 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:10,936 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:10,936 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:10,937 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:10,938 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:10,938 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:10,939 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:10,940 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:10,940 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:10,941 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:10,942 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:10,942 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:10,943 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:10,943 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:10,944 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:10,944 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:10,945 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:10,945 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:10,946 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:10,947 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:10,947 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:10,948 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:10,948 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:10,949 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:10,950 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:10,950 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:10,951 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:10,951 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:10,952 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:10,952 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:10,953 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:10,953 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:10,954 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:10,955 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:10,955 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:10,956 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:10,956 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:10,957 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:10,957 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:10,958 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:10,959 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:10,959 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:10,960 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:10,961 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:10,961 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:10,961 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:10,962 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:10,963 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:10,963 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:10,964 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:10,964 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:10,965 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:10,966 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:10,966 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:10,967 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:10,967 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:10,968 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:10,969 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:10,969 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:10,970 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:10,970 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:10,971 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:10,972 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:10,972 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:10,973 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:10,973 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:10,974 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:10,975 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:10,975 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:10,976 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:10,976 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:10,977 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:10,977 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:10,978 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:10,979 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:10,979 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:10,980 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:10,980 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:10,981 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:10,981 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:10,982 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:10,983 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:10,983 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:10,984 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:10,984 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:10,987 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:10,989 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:10,991 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:10,994 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:10,997 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:10,998 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:11,000 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:11,003 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:11,006 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:11,007 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:11,008 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:11,009 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:11,009 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:11,010 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:11,010 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:11,011 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:11,012 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:11,013 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:11,014 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:11,016 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:11,017 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:11,017 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:11,018 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:11,018 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:11,019 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:11,019 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:11,020 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:11,021 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:11,021 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:11,022 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:11,023 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:11,023 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:11,024 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:11,024 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:11,025 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:11,025 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:11,026 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:11,026 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:11,027 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:11,028 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:11,028 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:11,029 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:11,029 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:11,030 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:11,031 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:11,031 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:11,032 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:11,033 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:11,033 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:11,034 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:11,034 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:11,035 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:11,036 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:11,036 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:11,037 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:11,037 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:11,038 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:11,039 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:11,039 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:11,040 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:11,040 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:11,041 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:11,041 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:11,042 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:11,043 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:11,043 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:11,044 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:11,044 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:11,045 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:11,045 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:11,046 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:11,046 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:11,047 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:11,048 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:11,048 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:11,049 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:11,049 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:11,050 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:11,050 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:11,051 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:11,052 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:11,052 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:11,053 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:11,053 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:11,054 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:11,055 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:11,055 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:11,056 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:11,056 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:11,057 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:11,057 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:11,058 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:11,059 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:11,059 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:11,060 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:11,061 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:11,061 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:11,062 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:11,062 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:11,063 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:11,063 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:11,064 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:11,065 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:11,065 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:11,066 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:11,066 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:11,067 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:11,067 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:11,068 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:11,069 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:11,069 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:11,070 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:11,071 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:11,071 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:11,072 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:11,073 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:11,073 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:11,074 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:11,075 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:11,076 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:11,077 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:11,077 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:11,078 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:11,079 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:11,082 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:11,086 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:11,089 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:11,096 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:11,101 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:11,102 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:11,102 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:11,103 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:11,104 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:11,104 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:11,105 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:11,107 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:11,109 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:11,109 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:11,110 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:11,111 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:11,111 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:11,112 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:11,112 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:11,113 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:11,114 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:11,114 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:11,115 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:11,116 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:11,117 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:11,117 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:11,118 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:11,118 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:11,119 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:11,119 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:11,120 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:11,121 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:11,121 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:11,122 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:11,122 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# 2025-03-17 09:35:11,123 - LLMSR.fit - WARNING - regular curve fitting: invalid value encountered in power
# ...
# 2025-03-17 09:37:49,622 - LLMSR.kansr - INFO - LLM simplification step - trying 3 prompts,. each with 3 answers. Will attempt this process 2 times.
# 2025-03-17 09:37:49,623 - LLMSR.kansr - INFO - LLM simplification step - trying 3 answers per prompt for 3 prompts. We are on attempt #1
# 2025-03-17 09:37:49,623 - LLMSR.kansr - INFO - Using default system prompt for LLM simplification
# 2025-03-17 09:38:10,793 - LLMSR.kansr - INFO - LLM improvement responses (3 answers per prompt for 3 prompts, 9 responses, using 9): ['-(3685*(0.02719*x0**2 + 0.7831*sin(0.6188*x0) - tanh(0.42*x0))**3*exp(-0.1365*x0**2) - 1722*(0.02719*x0**2 + 0.7831*sin(0.6188*x0) - tanh(0.42*x0))**2*exp(-0.0453*x0**2) + (7.215*x0**3 + 22.07*x0**2 + 5.351*x0 - 0.5691*(x0**3 + 0.4714*x0**2 + 0.5972*x0 - 0.4332*exp(1.353*x0) + 0.678)**2 - 16.61*exp(1.353*x0) + 130.1*sin(0.6188*x0) - 0.03282*sin((0.0642*x0**2 + 51.24*sin(0.6188*x0) - 66.07*tanh(0.42*x0) - 1.259)*exp(0.05585*x0**2) - 0.16) - 150.9*tanh(0.42*x0) + 12.71)*exp(0.0485*x0**2) - 5.964*exp(-0.1305*x0**2))', '(-3685*(0.02719*x0**2 + 0.7831*sin(0.6188*x0) - tanh(0.42*x0))**3 + 1722*(0.02719*x0**2 + 0.7831*sin(0.6188*x0) - tanh(0.42*x0))**2)*exp(-0.1365*x0**2) - ((5.351 - 0.5691*(0.4714*x0**2 + 0.1641*x0**2 + 0.5972*x0 - 0.4332*exp(1.353*x0) + 0.678)**2)*exp(-0.0485*x0**2) + 130.1*sin(0.6188*x0) - 0.03282*sin(((0.0642*x0**2 + 51.24*sin(0.6188*x0) - 66.07*tanh(0.42*x0) - 1.259)*exp(0.05585*x0**2) - 0.16)) - 150.9*tanh(0.42*x0) + 12.71)*exp(-0.1083*x0**2) - 5.964*exp(-0.1305*x0**2)', '(-3685*(0.02719*x0**2 + 0.7831*sin(0.6188*x0))**3 + 1722*(0.02719*x0**2 + 0.7831*sin(0.6188*x0))**2)*exp(-0.1365*x0**2) + ((7.215*x0**3 + 22.07*x0**2 + 5.351*x0 - 0.5691*(0.4714*x0**2 + 0.1641*x0**2 + 0.5972*x0 - 0.4332*exp(1.353*x0) + 0.678)**2 - 16.61*exp(1.353*x0) + 130.1*sin(0.6188*x0)))*exp(-0.0485*x0**2) - 5.964*exp(-0.1305*x0**2)', '-3685*(0.02719*x0**2 + 0.7831*sin(0.6188*x0) - tanh(0.42*x0))**3 - 1722*(0.02719*x0**2 + 0.7831*sin(0.6188*x0) - tanh(0.42*x0))**2 + (7.215*x0**3 + 22.07*x0**2 + 5.351*x0 - 0.5691*(x0**3 + 0.4714*x0**2 + 0.5972*x0 - 0.4332*exp(1.353*x0) + 0.678)**2 - 16.61*exp(1.353*x0) + 130.1*sin(0.6188*x0) - 0.03282*sin(0.0642*x0**2 + 51.24*sin(0.6188*x0) - 66.07*tanh(0.42*x0) - 1.259) - 150.9*tanh(0.42*x0) + 12.71) - 5.964', '-3685*(0.0218*x0**2 + 0.7831*(0.6188*x0))**3 - 1722*(0.0218*x0**2 + 0.7831*(0.6188*x0))**2 - 5.964 + (7.215*x0**3 + 22.07*x0**2 + 5.351*x0 - 0.5691*(x0**3 + 0.4714*x0**2 + 0.5972*x0)**2 + 130.1*(0.6188*x0) + 12.71)', '-4407*(0.0218*x0**2 + 0.4833*x0)**2 + (7.215*x0**3 + 22.07*x0**2 + 5.351*x0 - 0.5691*(x0**3 + 0.4714*x0**2)**2 + 12.71)', '(-3685*(0.02719*x0**2 + 0.7831*sin(0.6188*x0) - tanh(0.42*x0))**3*exp(-0.1365*x0**2) - 1722*(0.02719*x0**2 + 0.7831*sin(0.6188*x0) - tanh(0.42*x0))**2*exp(-0.0453*x0**2) + (130.1*sin(0.6188*x0) - 150.9*tanh(0.42*x0) + 7.215*x0**3 + 22.07*x0**2 + 5.351*x0)*exp(0.0485*x0**2) - 22.8538)*exp(0.0485*x0**2)', '(-3685*(0.02719*x0**2 + 0.7831*sin(0.6188*x0) - tanh(0.42*x0))**3*exp(-0.1365*x0**2) - 1722*(0.02719*x0**2 + 0.7831*sin(0.6188*x0) - tanh(0.42*x0))**2*exp(-0.0453*x0**2) + (7.215*x0**3 + 22.07*x0**2 + 5.351*x0 + 130.1*sin(0.6188*x0) - 150.9*tanh(0.42*x0))*exp(0.0485*x0**2) - 22.8538)*exp(0.0485*x0**2)', '(-3685*(0.02719*x0**2 + 0.7831*sin(0.6188*x0) - tanh(0.42*x0))**3*exp(-0.1365*x0**2) - 1722*(0.02719*x0**2 + 0.7831*sin(0.6188*x0) - tanh(0.42*x0))**2*exp(-0.0453*x0**2) + (130.1*sin(0.6188*x0) - 150.9*tanh(0.42*x0) + 7.215*x0**3 + 22.07*x0**2 + 5.351*x0)*exp(0.0485*x0**2) - 22.8538)*exp(0.0485*x0**2)']
# 2025-03-17 09:38:10,795 - LLMSR.kansr - INFO - Trying LLM simplified expression #1: -(3685*(0.02719*x0**2 + 0.7831*sin(0.6188*x0) - tanh(0.42*x0))**3*exp(-0.1365*x0**2) - 1722*(0.02719*x0**2 + 0.7831*sin(0.6188*x0) - tanh(0.42*x0))**2*exp(-0.0453*x0**2) + (7.215*x0**3 + 22.07*x0**2 + 5.351*x0 - 0.5691*(x0**3 + 0.4714*x0**2 + 0.5972*x0 - 0.4332*exp(1.353*x0) + 0.678)**2 - 16.61*exp(1.353*x0) + 130.1*sin(0.6188*x0) - 0.03282*sin((0.0642*x0**2 + 51.24*sin(0.6188*x0) - 66.07*tanh(0.42*x0) - 1.259)*exp(0.05585*x0**2) - 0.16) - 150.9*tanh(0.42*x0) + 12.71)*exp(0.0485*x0**2) - 5.964*exp(-0.1305*x0**2))
# 2025-03-17 09:38:10,828 - LLMSR.kansr - INFO - LLM prompt number #1 n_chi2 without fitting: 6.8075e-05
# 2025-03-17 09:38:10,866 - LLMSR.fit - INFO - Fitting curve with JAX method BFGS, initial parameters [-0.0453 -0.1365 -0.1305...
# 2025-03-17 09:38:13,613 - LLMSR.fit - INFO - Fitting curve with initial parameters [-0.0453 -0.1365 -0.1305...
# 2025-03-17 09:38:53,377 - LLMSR.fit - INFO - Fitting curve with method lm,  with timeout: 5 seconds
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# File ~/Documents/Python/LLM_SR/LLMSR/fit.py:496, in _fit_with_all_methods(x, y, curve, params_initial, curve_fit_here, log_everything, stats, timeout_curve_fit, curve_str)
#     495     warnings.simplefilter("always")
# --> 496     params_opt, _ = curve_fit_here(curve, x, y, p0=params_initial, maxfev=1000*len(params_initial))
#     498 n_chi_squared = get_n_chi_squared(x, y, curve, params_opt)
#
# File ~/llm/lib/python3.13/site-packages/scipy/optimize/_minpack_py.py:1019, in curve_fit(f, xdata, ydata, p0, sigma, absolute_sigma, check_finite, bounds, method, jac, full_output, nan_policy, **kwargs)
#    1018     if ier not in [1, 2, 3, 4]:
# -> 1019         raise RuntimeError("Optimal parameters not found: " + errmsg)
#    1020 else:
#    1021     # Rename maxfev (leastsq) to max_nfev (least_squares), if specified.
#
# RuntimeError: Optimal parameters not found: Number of calls to function has reached maxfev = 29000.
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 2
#       1 # fit KAN
# ----> 2 best_expressions, best_chi_squareds, results_all_dicts = kan_sr.get_symbolic(population=10, generations=4, plot_parents=True, demonstrate_parent_plotting=True)
#
# File ~/Documents/Python/LLM_SR/LLMSR/kansr.py:285, in KANSR.get_symbolic(self, client, population, generations, temperature, gpt_model, exit_condition, verbose, use_async, plot_fit, plot_parents, demonstrate_parent_plotting, constant_on_failure, num_answers_per_prompt, timeout_simplify, custom_system_prompt_for_second_simplification, prune_small_terms, plot_all, original_f, number_of_prompts, simplification_gpt_model)
#     283 self.symbolic_expressions = self._sort_symbolic_expressions(result_of_kan_to_symbolic)
#     284 self.build_expression_tree()
# --> 285 self.optimised_expressions = self.optimise_expressions(client_to_use, simplification_gpt_model, x_data=self.dataset['train_input'].cpu().numpy(), y_data=self.dataset['train_label'].cpu().numpy(),
#     286                                                         custom_system_prompt=custom_system_prompt_for_second_simplification,
#     287                                                         prune_small_terms=prune_small_terms, plot_all=plot_all, original_f=original_f,
#     288                                                         num_answers_per_prompt=num_answers_per_prompt, timeout_simplify=timeout_simplify, number_of_prompts=number_of_prompts)
#     289 best_expressions, best_n_chi_squareds, results_all_dicts, all_results_sorted = self.optimised_expressions
#     290 self.results_all_dicts = results_all_dicts
#
# File ~/Documents/Python/LLM_SR/LLMSR/kansr.py:1011, in KANSR.optimise_expressions(self, client, simplification_gpt_model, x_data, y_data, custom_system_prompt, prune_small_terms, plot_all, original_f, num_answers_per_prompt, timeout_simplify, number_of_prompts, print_top_n)
#    1008 self.logger.info(f"expression: {best_result['expression']}")
#    1010 # Process LLM simplified expression
# -> 1011 llm_result, all_llm_results = self._process_expression_using_llm(
#    1012     best_result['expression'], x_data, y_data, Ninputs, ranges,
#    1013     client, simplification_gpt_model, custom_system_prompt, num_answers_per_prompt,
#    1014     timeout_simplify, number_of_prompts, prune_small_terms
#    1015 )
#    1016 self._update_best_result(best_result, llm_result)
#    1018 # Add best LLM result to all_results if it has a valid expression
#
# File ~/Documents/Python/LLM_SR/LLMSR/kansr.py:869, in KANSR._process_expression_using_llm(self, best_expression, x_data, y_data, Ninputs, ranges, client, gpt_model, custom_system_prompt, num_answers_per_prompt, timeout_simplify, number_of_prompts, prune_small_terms)
#     867 self.logger.info(f"LLM simplification step - trying {number_of_prompts} prompts,. each with {num_answers_per_prompt} answers. Will attempt this process {number_of_attempts} times.")
#     868 for attempt_num in range(number_of_attempts):
# --> 869     attempt_result, attempt_all_results = self._attempt_llm_simplification(
#     870         best_expression, x_data, y_data, Ninputs, ranges,
#     871         client_to_use, gpt_model, custom_system_prompt,
#     872         num_answers_per_prompt, timeout_simplify, prune_amount,
#     873         attempt_num, number_of_prompts = number_of_prompts
#     874     )
#     876     # Add all valid results to our collection
#     877     all_llm_results.extend(attempt_all_results)
#
# File ~/Documents/Python/LLM_SR/LLMSR/kansr.py:782, in KANSR._attempt_llm_simplification(self, best_expression, x_data, y_data, Ninputs, ranges, client_to_use, gpt_model, custom_system_prompt, num_answers_per_prompt, timeout_simplify, prune_amount, attempt_num, number_of_prompts, timeout_regular)
#     779 curve_np, curve_ansatz_np = self._convert_to_np_function(curve_ansatz_str_np, Ninputs, params=True, return_string=True)
#     781 try:
# --> 782     params_opt, n_chi_squared_after_fitting = self._fit_params(
#     783         x_data, y_data, curve_np, params_initial, curve_ansatz_np,
#     784         log_methods=True, log_everything=True, timeout_regular=timeout_regular
#     785     )
#     786     self.logger.info(f"LLM prompt number #{answer_num} n_chi2 after fitting: {n_chi_squared_after_fitting:.4e} for {curve_ansatz_np}, params opt.: {str(params_opt[:3])[:-1]}...")
#     787     n_chi_squared_after_llm_fitting = n_chi_squared_after_fitting
#
# File ~/Documents/Python/LLM_SR/LLMSR/kansr.py:2147, in KANSR._fit_params(self, x_data, y_data, curve_np, params_initial, curve_ansatz_np, log_methods, log_everything, try_harder_jax, timeout_regular)
#    2145 try:
#    2146     self.logger.debug(f"Fitting parameters with initial parameters {str(params_initial[:3])[:-1]}...")
# -> 2147     params_opt, n_chi_squared = fit_curve_with_guess_jax(
#    2148         x_data, y_data, curve_np, params_initial,
#    2149         log_everything=log_everything,  # We don't want all logs by default
#    2150         log_methods=log_methods,      # But we do want to see which methods were used
#    2151         then_do_reg_fitting=True,
#    2152         numpy_curve_str=curve_ansatz_np,
#    2153         timeout_regular=timeout_regular
#    2154     )
#    2155     if not np.isinf(n_chi_squared):
#    2156         return params_opt, n_chi_squared
#
# File ~/Documents/Python/LLM_SR/LLMSR/fit.py:820, in fit_curve_with_guess_jax(x, y, curve, params_initial, log_everything, log_methods, then_do_reg_fitting, numpy_curve_str, stats, timeout_regular)
#     818 # Try additional optimisation methods if requested
#     819 if then_do_reg_fitting:
# --> 820     post_optimised = _run_post_jax_optimisations(
#     821         x, y, jax_curve, np_curve, result.params, result.n_chi_squared,
#     822         log_everything, stats, timeout_regular, result.methods_used)
#     824     # Update result if post-optimisation improved the fit
#     825     if post_optimised.success and post_optimised.n_chi_squared < result.n_chi_squared:
#
# File ~/Documents/Python/LLM_SR/LLMSR/fit.py:970, in _run_post_jax_optimisations(x, y, jax_curve, np_curve, best_params, best_n_chi_squared, log_everything, stats, timeout_regular, methods_used)
#     968 try:
#     969     reg_curve = np_curve if np_curve is not None else jax_curve
# --> 970     reg_params, reg_n_chi_squared = fit_curve_with_guess(
#     971         np.array(x), np.array(y), reg_curve,
#     972         np.array(best_params), try_all_methods=True,
#     973         log_everything=log_everything,
#     974         stats=stats, timeout_curve_fit=timeout_regular
#     975     )
#     976     methods_used.append("regular_after_jax")
#     978     # Compare results and take the better one
#
# File ~/Documents/Python/LLM_SR/LLMSR/fit.py:408, in fit_curve_with_guess(x, y, curve, params_initial, try_all_methods, log_everything, stats, curve_str, timeout_curve_fit)
#     405 with WarningManager(stats, "regular curve fitting", print_warnings=log_everything) as warning_mgr:
#     406     # Attempt to fit the curve
#     407     if try_all_methods:
# --> 408         result = _fit_with_all_methods(
#     409             x, y, curve, params_initial, curve_fit_here,
#     410             log_everything, stats, timeout_curve_fit, curve_str
#     411         )
#     412     else:
#     413         result = _fit_with_default_method(
#     414             x, y, curve, params_initial, curve_fit_here,
#     415             log_everything, stats
#     416         )
#
# File ~/Documents/Python/LLM_SR/LLMSR/fit.py:527, in _fit_with_all_methods(x, y, curve, params_initial, curve_fit_here, log_everything, stats, timeout_curve_fit, curve_str)
#     525 warnings.simplefilter("always")
#     526 with stopit.ThreadingTimeout(timeout_curve_fit) as timeout_ctx:
# --> 527     params_opt, _ = curve_fit_here(curve, x, y, p0=params_initial,
#     528                                  method=method, maxfev=1000*len(params_initial))
#     530 if timeout_ctx.state == timeout_ctx.TIMED_OUT:
#     531     if log_everything:
#
# File ~/llm/lib/python3.13/site-packages/scipy/optimize/_minpack_py.py:1014, in curve_fit(f, xdata, ydata, p0, sigma, absolute_sigma, check_finite, bounds, method, jac, full_output, nan_policy, **kwargs)
#    1011 if ydata.size != 1 and n > ydata.size:
#    1012     raise TypeError(f"The number of func parameters={n} must not"
#    1013                     f" exceed the number of data points={ydata.size}")
# -> 1014 res = leastsq(func, p0, Dfun=jac, full_output=1, **kwargs)
#    1015 popt, pcov, infodict, errmsg, ier = res
#    1016 ysize = len(infodict['fvec'])
#
# File ~/llm/lib/python3.13/site-packages/scipy/optimize/_minpack_py.py:438, in leastsq(func, x0, args, Dfun, full_output, col_deriv, ftol, xtol, gtol, maxfev, epsfcn, factor, diag)
#     436     if maxfev == 0:
#     437         maxfev = 200*(n + 1)
# --> 438     retval = _minpack._lmdif(func, x0, args, full_output, ftol, xtol,
#     439                              gtol, maxfev, epsfcn, factor, diag)
#     440 else:
#     441     if col_deriv:
#
# File ~/llm/lib/python3.13/site-packages/scipy/optimize/_minpack_py.py:515, in _lightweight_memoizer.<locals>._memoized_func(params)
#     513 def _memoized_func(params):
#     514     if _memoized_func.skip_lookup:
# --> 515         return f(params)
#     517     if np.all(_memoized_func.last_params == params):
#     518         return _memoized_func.last_val
#
# File ~/llm/lib/python3.13/site-packages/scipy/optimize/_minpack_py.py:539, in _wrap_func.<locals>.func_wrapped(params)
#     538 def func_wrapped(params):
# --> 539     return func(xdata, *params) - ydata
#
# File <string>:1, in <lambda>(x0, *params)
#
# KeyboardInterrupt:

# %%
print(kan_sr.results_all_dicts[0])
# Out:
# {'raw_expression': '-0.002972321910964*x0**9 - 0.0299431404804*x0**8 - 0.130662120097026*x0**7 - 0.172360667935118*x0**6 + 0.575491363498297*x0**5 + 2.50564397106104*x0**4 + 3.73462989189019*x0**3 + 6.77568225436405*x0**2 + 2.39271390567917*x0 - 1.8191*np.sin(0.48025838*x0**3 + 1.612706*x0**2 + 1.62186289*x0 - 1.57430173) + 5.58711084925009', 'raw_n_chi_squared': Array(2.4061227, dtype=float32), 'final_KAN_expression': '1.0*x0**6 + 6.2832*x0**3 + 9.8696', 'n_chi_squared_KAN_final': Array(7.7674735e-11, dtype=float32), 'final_LLM_expression': 'x0**6 + 6.2832*x0**3 + 9.8696', 'n_chi_squared_LLM_final': 48.76724624633789, 'best_expression': '-0.002972321910964*x0**9 - 0.0299431404804*x0**8 - 0.130662120097026*x0**7 - 0.172360667935118*x0**6 + 0.575491363498297*x0**5 + 2.50564397106104*x0**4 + 3.73462989189019*x0**3 + 6.77568225436405*x0**2 + 2.39271390567917*x0 - 1.8191*np.sin(0.48025838*x0**3 + 1.612706*x0**2 + 1.62186289*x0 - 1.57430173) + 5.58711084925009', 'best_n_chi_squared': Array(2.4061227, dtype=float32), 'best_expression_index': 0, 'best_fit_type': 'raw'}

# %%
kan_sr.plot_results(ranges, kan_sr.results_all_dicts[0],title="KAN Symbolic Regression Results")
# Out:
# 2025-03-12 18:52:51,474 - LLMSR.kansr - INFO - Using internal dataset for plotting
# 2025-03-12 18:52:51,475 - LLMSR.kansr - INFO - Using provided ranges: [-2, 2]
# 2025-03-12 18:52:51,475 - LLMSR.kansr - INFO - Using self.f function for ground truth
# 2025-03-12 18:52:51,485 - LLMSR.kansr - INFO - Plotting raw expression
# 2025-03-12 18:52:51,486 - LLMSR.kansr - WARNING - Error plotting simplified expression: Too many indices: 0-dimensional array indexed with 1 regular index.
# (<Figure size 1000x600 with 1 Axes>,
#  <Axes: title={'center': 'KAN Symbolic Regression Results'}, xlabel='x', ylabel='y'>)

# %%
best_expressions, best_chi_squareds, results_all_dicts
# Out:
# (['-0.002972321910964*x0**9 - 0.0299431404804*x0**8 - 0.130662120097026*x0**7 - 0.172360667935118*x0**6 + 0.575491363498297*x0**5 + 2.50564397106104*x0**4 + 3.73462989189019*x0**3 + 6.77568225436405*x0**2 + 2.39271390567917*x0 - 1.8191*np.sin(0.48025838*x0**3 + 1.612706*x0**2 + 1.62186289*x0 - 1.57430173) + 5.58711084925009'],
#  [Array(2.4061227, dtype=float32)],
#  [{'raw_expression': '-0.002972321910964*x0**9 - 0.0299431404804*x0**8 - 0.130662120097026*x0**7 - 0.172360667935118*x0**6 + 0.575491363498297*x0**5 + 2.50564397106104*x0**4 + 3.73462989189019*x0**3 + 6.77568225436405*x0**2 + 2.39271390567917*x0 - 1.8191*np.sin(0.48025838*x0**3 + 1.612706*x0**2 + 1.62186289*x0 - 1.57430173) + 5.58711084925009',
#    'raw_n_chi_squared': Array(2.4061227, dtype=float32),
#    'final_KAN_expression': '1.0*x0**6 + 6.2832*x0**3 + 9.8696',
#    'n_chi_squared_KAN_final': Array(7.7674735e-11, dtype=float32),
#    'final_LLM_expression': 'x0**6 + 6.2832*x0**3 + 9.8696',
#    'n_chi_squared_LLM_final': 48.76724624633789,
#    'best_expression': '-0.002972321910964*x0**9 - 0.0299431404804*x0**8 - 0.130662120097026*x0**7 - 0.172360667935118*x0**6 + 0.575491363498297*x0**5 + 2.50564397106104*x0**4 + 3.73462989189019*x0**3 + 6.77568225436405*x0**2 + 2.39271390567917*x0 - 1.8191*np.sin(0.48025838*x0**3 + 1.612706*x0**2 + 1.62186289*x0 - 1.57430173) + 5.58711084925009',
#    'best_n_chi_squared': Array(2.4061227, dtype=float32),
#    'best_expression_index': 0,
#    'best_fit_type': 'raw'}])

# %%
import numpy as np
f_orig = lambda x0: (x0**3 + torch.pi)**2
f_kan_fitted= lambda x0: eval(results_all_dicts[0]['final_KAN_expression'])
f_llm_fitted = lambda x0: eval(results_all_dicts[0]['final_LLM_expression'])
f_best_fitted = lambda x0: eval(best_expressions[0])
xs = np.arange(ranges[0], ranges[1], .1)

# Convert to tensor for model evaluation
xs_tensor = torch.tensor(xs, dtype=torch.float32).unsqueeze(1).to(device)

# Evaluate the KAN models
raw_kan_outputs = kan_sr.raw_model(xs_tensor).cpu().detach().numpy().flatten()
pruned_kan_outputs = kan_sr.model(xs_tensor).cpu().detach().numpy().flatten()

# Plot all expressions and models
plt.figure(figsize=(10, 6))
plt.plot(xs, [f_best_fitted(x) for x in xs], linestyle=':', label="KANSR (best fit)", linewidth=1)  
plt.plot(xs, [f_orig(x) for x in xs], linestyle='-', c='black', label="Original", linewidth=4, alpha=0.2)
plt.plot(xs, [f_kan_fitted(x) for x in xs], linestyle='-.', label="KANSR (final refitted from KAN)", linewidth=1)
plt.plot(xs, [f_llm_fitted(x) for x in xs], linestyle=':', label="KANSR (simplified from KAN by LLM)", linewidth=1)
plt.plot(xs, raw_kan_outputs, linestyle='--', label="Raw KAN model", linewidth=1.5)
plt.plot(xs, pruned_kan_outputs, linestyle=':', label="Pruned KAN model", linewidth=3)
plt.legend()
plt.title("Expression and Model Comparison")
plt.show()

# %% [markdown]
# # Try $e^{1.83169-3.35509/x}$

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)

# initialize KAN with G=3
model = KAN(width=[1,4,1], grid=7, k=3, seed=17, device=device, symbolic_enabled=False)

# create dataset
f = lambda x: np.exp(1.83169-3.35509/x)
ranges = [0.1, 2.]
dataset = create_dataset(f, n_var=1, ranges=ranges, train_num=10000, test_num=1000, device=device)
res_kan_training = model.fit(dataset, opt="LBFGS", steps=50);
model.plot()
# Out:
# /var/folders/n5/4xlf9f2j41z1r42htkz4vw0m0000gn/T/ipykernel_6753/626955180.py:8: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   f = lambda x: np.exp(1.83169-3.35509/x)
# cpu
# checkpoint directory created: ./model
# saving model version 0.0
# | train_loss: 5.90e-06 | test_loss: 5.76e-06 | reg: 9.11e+00 | : 100%|█| 50/50 [00:25<00:00,  1.93it
# saving model version 0.1
